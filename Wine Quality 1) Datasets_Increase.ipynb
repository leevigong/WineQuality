# %% [markdown]
# # 필요한 모듈 설정

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib import patches
# %matplotlib inline

# %% [markdown]
# # 데이터 로드

# %%
wine = pd.read_csv('WineQT_add.csv')
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ## 데이터 크기, 결측치 확인

# %%
wine.shape
# Out:
# (2742, 12)

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Scaled, Normalization

# %%
from sklearn import preprocessing
from imblearn.over_sampling import SMOTE 

oversample = SMOTE()
features, labels =  oversample.fit_resample(wine.drop(["quality"],axis=1), wine["quality"])
scaler = preprocessing.MinMaxScaler()
scaled_data = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
scaled_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.247788          0.397260     0.000000        0.068493   0.106845
# 1          0.283186          0.520548     0.000000        0.116438   0.143573
# 2          0.283186          0.438356     0.040000        0.095890   0.133556
# 3          0.584071          0.109589     0.560000        0.068493   0.105175
# 4          0.247788          0.397260     0.000000        0.068493   0.106845
# ...             ...               ...          ...             ...        ...
# 6979       0.453792          0.146879     0.561115        0.147639   0.106288
# 6980       0.085201          0.408212     0.042555        0.044445   0.054470
# 6981       0.536486          0.155597     0.522458        0.140977   0.097300
# 6982       0.292035          0.287671     0.340000        0.109589   0.106845
# 6983       0.242280          0.168646     0.303112        0.065907   0.094155
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                0.140845              0.098940  0.567548  0.606299
# 1                0.338028              0.215548  0.494126  0.362205
# 2                0.197183              0.169611  0.508811  0.409449
# 3                0.225352              0.190813  0.582232  0.330709
# 4                0.140845              0.098940  0.567548  0.606299
# ...                   ...                   ...       ...       ...
# 6979             0.147885              0.098547  0.570813  0.336390
# 6980             0.238817              0.288437  0.127342  0.628083
# 6981             0.056338              0.034336  0.526264  0.328773
# 6982             0.098592              0.038869  0.167401  0.362205
# 6983             0.216586              0.069102  0.314606  0.391250
#
#       sulphates   alcohol
# 0      0.137725  0.153846
# 1      0.209581  0.215385
# 2      0.191617  0.215385
# 3      0.149701  0.215385
# 4      0.137725  0.153846
# ...         ...       ...
# 6979   0.308050  0.497429
# 6980   0.293413  0.755304
# 6981   0.201214  0.423207
# 6982   0.233533  0.723077
# 6983   0.232737  0.456751
#
# [6984 rows x 11 columns]

# %%
normalized_arr = preprocessing.normalize(scaled_data)
normalized_data = pd.DataFrame(normalized_arr, columns=features.columns)
normalized_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.248124          0.397799     0.000000        0.068586   0.106990
# 1          0.281540          0.517522     0.000000        0.115762   0.142738
# 2          0.302173          0.467748     0.042682        0.102320   0.142511
# 3          0.514873          0.096605     0.493654        0.060378   0.092715
# 4          0.248124          0.397799     0.000000        0.068586   0.106990
# ...             ...               ...          ...             ...        ...
# 6979       0.385131          0.124656     0.476216        0.125301   0.090206
# 6980       0.072315          0.346471     0.036119        0.037723   0.046232
# 6981       0.485052          0.140680     0.472369        0.127461   0.087972
# 6982       0.284336          0.280087     0.331036        0.106700   0.104028
# 6983       0.278142          0.193610     0.347979        0.075662   0.108091
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                0.141036              0.099074  0.568317  0.607121
# 1                0.336063              0.214295  0.491254  0.360099
# 2                0.210404              0.180984  0.542926  0.436902
# 3                0.198654              0.168206  0.513252  0.291528
# 4                0.141036              0.099074  0.568317  0.607121
# ...                   ...                   ...       ...       ...
# 6979             0.125510              0.083636  0.484446  0.285492
# 6980             0.202696              0.244812  0.108082  0.533086
# 6981             0.050937              0.031044  0.475810  0.297253
# 6982             0.095992              0.037845  0.162988  0.352656
# 6983             0.248646              0.079331  0.361174  0.449164
#
#       sulphates   alcohol
# 0      0.137911  0.154055
# 1      0.208363  0.214133
# 2      0.204465  0.229826
# 3      0.131965  0.189867
# 4      0.137911  0.154055
# ...         ...       ...
# 6979   0.261441  0.422165
# 6980   0.249035  0.641065
# 6981   0.181923  0.382633
# 6982   0.227376  0.704014
# 6983   0.267187  0.524360
#
# [6984 rows x 11 columns]

# %%
from numpy import log
import warnings
warnings.filterwarnings(action='ignore')
unskew_data = normalized_data.copy(deep=True)

# %% [markdown]
# ## Classifier Models

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn import metrics

# %%
rnd_clf = RandomForestClassifier()
log_clf = LogisticRegression()
dt_clf = DecisionTreeClassifier()
kn_clf = KNeighborsClassifier()
svm_clf = SVC()

models = [rnd_clf, dt_clf, kn_clf, svm_clf, log_clf]

# %% [markdown]
# ## train / test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(unskew_data, labels, test_size=0.2, random_state=42)

# %% [markdown]
# ## fit

# %%
for m in models:
    m.fit(X_train, y_train)

# %% [markdown]
# ## predict

# %%
accuracy = []
precision = []
recall = []
F1 = []

for m in models:
    y_pred = m.predict(X_test)
    print(m.__class__.__name__,'Acc: ', accuracy_score(y_test,y_pred))
    print(m.__class__.__name__,'Precision: ', precision_score(y_test,y_pred, average = "macro"))
    print(m.__class__.__name__,'Recall: ', recall_score(y_test,y_pred, average = "macro"))
    print(m.__class__.__name__,'F1: ', f1_score(y_test,y_pred, average = "macro"))
    
    print("")
    
    acc = accuracy_score(y_test,y_pred)
    pcs = precision_score(y_test,y_pred, average = "macro")
    rec = recall_score(y_test,y_pred, average = "macro")
    f1 = f1_score(y_test,y_pred, average = "macro")
    
    accuracy.append(acc)
    precision.append(pcs)
    recall.append(rec)
    F1.append(f1)
    
    print("")
# Out:
# RandomForestClassifier Acc:  0.9606299212598425
# RandomForestClassifier Precision:  0.9611436029974653
# RandomForestClassifier Recall:  0.9625950587552753
# RandomForestClassifier F1:  0.9616601947244511
#
#
# DecisionTreeClassifier Acc:  0.9241231209735147
# DecisionTreeClassifier Precision:  0.9262004483883524
# DecisionTreeClassifier Recall:  0.9262349932058799
# DecisionTreeClassifier F1:  0.9257015484804317
#
#
# KNeighborsClassifier Acc:  0.8503937007874016
# KNeighborsClassifier Precision:  0.8473581423739023
# KNeighborsClassifier Recall:  0.8550156991441994
# KNeighborsClassifier F1:  0.8472485689880761
#
#
# SVC Acc:  0.7086614173228346
# SVC Precision:  0.6960901221846613
# SVC Recall:  0.7171968447483908
# SVC F1:  0.697373710755314
#
#
# LogisticRegression Acc:  0.5275590551181102
# LogisticRegression Precision:  0.5123412276939955
# LogisticRegression Recall:  0.537339256540284
# LogisticRegression F1:  0.5173485519131541

# %% [markdown]
# # Metrics Score

# %%
metrics = [accuracy, precision, recall , F1]
total = []

for i in range(5):
    avg = 0
    for mt in metrics:
        avg += mt[i]*0.25
    total.append(avg)
        
print(total)
# Out:
# [0.9615071944342585, 0.9255650277620446, 0.8500040278233949, 0.7048305237528002, 0.5236470228163859]
